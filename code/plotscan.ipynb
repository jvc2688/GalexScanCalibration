# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from astropy.io import fits as pyfits
import numpy as np
from astropy.coordinates import SkyCoord
from astropy.coordinates import ICRS, Galactic, FK4, FK5
from astropy.coordinates import Angle, Latitude, Longitude
from astropy.wcs import WCS
import aplpy
from matplotlib.colors import LogNorm

# %%
sky='18-28'
fits = pyfits.open('/Users/dunwang/Desktop/galex/fits/scan_map/count_map_'+sky+'_in.fits')

# %%
data = fits[0].data
wcs = WCS(fits[0].header)

# %%
fig = plt.figure()
fig.set_size_inches(25,50)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
image = data
plt.imshow(image, cmap='gray_r', interpolation=None,  norm=LogNorm(0,np.max(image)), vmin=0.01, vmax=5, origin='lower')
plt.savefig('/Users/dunwang/Desktop/galex/plots/'+sky+'.png')
plt.clf()

# %%
wcs[]

# %%
del fig

# %%
from matplotlib.colors import LogNorm
size=25
step = 4000
for i in range(13):
    fig = plt.figure()
    fig.set_size_inches(size*7600./4000,size)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    image = data[1600+i*step:1600+(i+1)*step,1000:8600]
    plt.imshow(image, cmap='gray_r', interpolation=None,  norm=LogNorm(0,1000), vmin=0.01, vmax=5)
    plt.savefig('/Users/dunwang/Desktop/galex/plots/'+'_%04d'%(i)+'.png')
    plt.clf()
    del fig

# %%
image = data[20600:21000,2500:2900]
fig = plt.figure()
size=10
fig.set_size_inches(size*7700./5000,size)
plt.imshow(image, cmap='gray_r', norm=LogNorm(), vmin=0.01, vmax=5)
plt.colorbar()

# %%
gc = aplpy.FITSFigure('/Users/dunwang/Desktop/count_map_5-23-cal-sec_in_dis.fits', figsize=(10,9))

# %%
gc.show_grayscale()
# Out:
# INFO: Auto-setting vmin to -2.179e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.419e-01 [aplpy.core]

# %%
gc.set_tick_labels_font(size='small')
gc.recenter(1.41, 2.414, radius=None, width=3.2, height=1.5)
gc.show_grayscale()
gc.add_colorbar()

gc.save('tutorial.png')
# Out:
# INFO: Auto-setting vmin to -2.179e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.419e-01 [aplpy.core]

# %%
cat = pyfits.open('/Users/dunwang/Desktop/galex/fits/scan_map/tycho2.fits')

# %%
mask = (cat[1].data['Glon']>23.8) & (cat[1].data['Glon']<23.98) & (cat[1].data['Glat']>-5.45) & (cat[1].data['Glat']<-5.35)

# %%
(cat[1].data['Glon']>23.8)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], dtype=bool)

# %%
np.sum(mask)
# Out:
# 3

# %%
cat[1].data['Glon'][mask]
# Out:
# array([ 23.85950089,  23.89240074,  23.96879959], dtype=float32)

# %%
cat[1].data['Glat'][mask]
# Out:
# array([-5.3913002 , -5.40180016, -5.36560011], dtype=float32)
